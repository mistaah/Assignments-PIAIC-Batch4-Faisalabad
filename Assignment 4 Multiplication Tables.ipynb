# %%
start=int(input("Enter First Value:\n"))
end=int(input("Enter Second Value:\n"))
first_start=start
first_end=end
second_start=start
second_end=end
print("*"*50)
print("*"*50)
print("*"*50)
print("First Output : \n")
print("*"*50)
print("*"*50)
print("*"*50)
while True:  
    for i in range(1, 11):
        print(f"{first_start} * {i} = {i * first_start}")
        
    first_start+=1
    print("")
    print("")

    if(first_start>first_end):  
        break  
#print("*"*50)
#print("*"*50)
#print("*"*50)
#print("Second Output : \n")
#print("*"*50)
#print("*"*50)
#print("*"*50)

#while True:  
 #   for i in range(1, 11):
  #      print(f"{second_start} * {i} = {i * second_start}")
        
        
   # second_start+=1
    #print(end = "\t")
    #print("",end = "\t")
    #print("",end = "\t")

    #if(second_start>second_end):  
     #   break
# Out:
# Enter First Value:
# 1
# Enter Second Value:
# 3
# **************************************************
# **************************************************
# **************************************************
# First Output :
#
# **************************************************
# **************************************************
# **************************************************
# 1 * 1 = 1
# 1 * 2 = 2
# 1 * 3 = 3
# 1 * 4 = 4
# 1 * 5 = 5
# 1 * 6 = 6
# 1 * 7 = 7
# 1 * 8 = 8
# 1 * 9 = 9
# 1 * 10 = 10
#
#
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20
#
#
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 3 * 10 = 30
